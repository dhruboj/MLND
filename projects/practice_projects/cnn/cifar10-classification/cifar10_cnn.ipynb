# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 15s 0us/step

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='Adagrad', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 13s - loss: 1.0290 - acc: 0.6364 - val_loss: 1.0224 - val_acc: 0.6304
#
# Epoch 00001: val_loss improved from inf to 1.02242, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 14s - loss: 1.0143 - acc: 0.6396 - val_loss: 0.9582 - val_acc: 0.6618
#
# Epoch 00002: val_loss improved from 1.02242 to 0.95818, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 15s - loss: 1.0023 - acc: 0.6453 - val_loss: 0.9416 - val_acc: 0.6664
#
# Epoch 00003: val_loss improved from 0.95818 to 0.94164, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 13s - loss: 0.9878 - acc: 0.6519 - val_loss: 0.9331 - val_acc: 0.6662
#
# Epoch 00004: val_loss improved from 0.94164 to 0.93311, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 13s - loss: 0.9764 - acc: 0.6551 - val_loss: 0.9167 - val_acc: 0.6718
#
# Epoch 00005: val_loss improved from 0.93311 to 0.91666, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 13s - loss: 0.9662 - acc: 0.6589 - val_loss: 0.9147 - val_acc: 0.6722
#
# Epoch 00006: val_loss improved from 0.91666 to 0.91474, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 13s - loss: 0.9563 - acc: 0.6626 - val_loss: 0.9089 - val_acc: 0.6770
#
# Epoch 00007: val_loss improved from 0.91474 to 0.90890, saving model to model.weights.best.hdf5
# Epoch 8/100
#  - 13s - loss: 0.9466 - acc: 0.6636 - val_loss: 0.9105 - val_acc: 0.6702
#
# Epoch 00008: val_loss did not improve from 0.90890
# Epoch 9/100
#  - 13s - loss: 0.9387 - acc: 0.6679 - val_loss: 0.9005 - val_acc: 0.6694
#
# Epoch 00009: val_loss improved from 0.90890 to 0.90050, saving model to model.weights.best.hdf5
# Epoch 10/100
#  - 13s - loss: 0.9350 - acc: 0.6696 - val_loss: 0.8966 - val_acc: 0.6816
#
# Epoch 00010: val_loss improved from 0.90050 to 0.89664, saving model to model.weights.best.hdf5
# Epoch 11/100
#  - 13s - loss: 0.9300 - acc: 0.6724 - val_loss: 0.8882 - val_acc: 0.6806
#
# Epoch 00011: val_loss improved from 0.89664 to 0.88817, saving model to model.weights.best.hdf5
# Epoch 12/100
#  - 14s - loss: 0.9224 - acc: 0.6743 - val_loss: 0.8825 - val_acc: 0.6838
#
# Epoch 00012: val_loss improved from 0.88817 to 0.88246, saving model to model.weights.best.hdf5
# Epoch 13/100
#  - 13s - loss: 0.9120 - acc: 0.6784 - val_loss: 0.8798 - val_acc: 0.6844
#
# Epoch 00013: val_loss improved from 0.88246 to 0.87975, saving model to model.weights.best.hdf5
# Epoch 14/100
#  - 13s - loss: 0.9022 - acc: 0.6812 - val_loss: 0.8603 - val_acc: 0.6898
#
# Epoch 00014: val_loss improved from 0.87975 to 0.86031, saving model to model.weights.best.hdf5
# Epoch 15/100
#  - 13s - loss: 0.8984 - acc: 0.6831 - val_loss: 0.8595 - val_acc: 0.6944
#
# Epoch 00015: val_loss improved from 0.86031 to 0.85949, saving model to model.weights.best.hdf5
# Epoch 16/100
#  - 13s - loss: 0.8920 - acc: 0.6844 - val_loss: 0.8593 - val_acc: 0.6968
#
# Epoch 00016: val_loss improved from 0.85949 to 0.85933, saving model to model.weights.best.hdf5
# Epoch 17/100
#  - 13s - loss: 0.8851 - acc: 0.6870 - val_loss: 0.8459 - val_acc: 0.6954
#
# Epoch 00017: val_loss improved from 0.85933 to 0.84587, saving model to model.weights.best.hdf5
# Epoch 18/100
#  - 13s - loss: 0.8795 - acc: 0.6907 - val_loss: 0.8539 - val_acc: 0.6942
#
# Epoch 00018: val_loss did not improve from 0.84587
# Epoch 19/100
#  - 13s - loss: 0.8701 - acc: 0.6918 - val_loss: 0.8436 - val_acc: 0.6972
#
# Epoch 00019: val_loss improved from 0.84587 to 0.84358, saving model to model.weights.best.hdf5
# Epoch 20/100
#  - 13s - loss: 0.8696 - acc: 0.6954 - val_loss: 0.8330 - val_acc: 0.7030
#
# Epoch 00020: val_loss improved from 0.84358 to 0.83296, saving model to model.weights.best.hdf5
# Epoch 21/100
#  - 13s - loss: 0.8651 - acc: 0.6948 - val_loss: 0.8341 - val_acc: 0.7032
#
# Epoch 00021: val_loss did not improve from 0.83296
# Epoch 22/100
#  - 13s - loss: 0.8590 - acc: 0.6977 - val_loss: 0.8343 - val_acc: 0.7070
#
# Epoch 00022: val_loss did not improve from 0.83296
# Epoch 23/100
#  - 13s - loss: 0.8520 - acc: 0.7009 - val_loss: 0.8367 - val_acc: 0.7016
#
# Epoch 00023: val_loss did not improve from 0.83296
# Epoch 24/100
#  - 13s - loss: 0.8472 - acc: 0.7006 - val_loss: 0.8222 - val_acc: 0.7062
#
# Epoch 00024: val_loss improved from 0.83296 to 0.82221, saving model to model.weights.best.hdf5
# Epoch 25/100
#  - 13s - loss: 0.8414 - acc: 0.7066 - val_loss: 0.8197 - val_acc: 0.7086
#
# Epoch 00025: val_loss improved from 0.82221 to 0.81969, saving model to model.weights.best.hdf5
# Epoch 26/100
#  - 13s - loss: 0.8358 - acc: 0.7059 - val_loss: 0.8161 - val_acc: 0.7096
#
# Epoch 00026: val_loss improved from 0.81969 to 0.81606, saving model to model.weights.best.hdf5
# Epoch 27/100
#  - 13s - loss: 0.8346 - acc: 0.7060 - val_loss: 0.8193 - val_acc: 0.7102
#
# Epoch 00027: val_loss did not improve from 0.81606
# Epoch 28/100
#  - 13s - loss: 0.8306 - acc: 0.7058 - val_loss: 0.8060 - val_acc: 0.7154
#
# Epoch 00028: val_loss improved from 0.81606 to 0.80599, saving model to model.weights.best.hdf5
# Epoch 29/100
#  - 13s - loss: 0.8257 - acc: 0.7077 - val_loss: 0.8040 - val_acc: 0.7154
#
# Epoch 00029: val_loss improved from 0.80599 to 0.80397, saving model to model.weights.best.hdf5
# Epoch 30/100
#  - 13s - loss: 0.8232 - acc: 0.7110 - val_loss: 0.8064 - val_acc: 0.7104
#
# Epoch 00030: val_loss did not improve from 0.80397
# Epoch 31/100
#  - 13s - loss: 0.8176 - acc: 0.7108 - val_loss: 0.8030 - val_acc: 0.7144
#
# Epoch 00031: val_loss improved from 0.80397 to 0.80303, saving model to model.weights.best.hdf5
# Epoch 32/100
#  - 13s - loss: 0.8102 - acc: 0.7149 - val_loss: 0.8090 - val_acc: 0.7148
#
# Epoch 00032: val_loss did not improve from 0.80303
# Epoch 33/100
#  - 13s - loss: 0.8045 - acc: 0.7179 - val_loss: 0.8081 - val_acc: 0.7162
#
# Epoch 00033: val_loss did not improve from 0.80303
# Epoch 34/100
#  - 13s - loss: 0.8011 - acc: 0.7184 - val_loss: 0.7978 - val_acc: 0.7186
#
# Epoch 00034: val_loss improved from 0.80303 to 0.79780, saving model to model.weights.best.hdf5
# Epoch 35/100
#  - 13s - loss: 0.7996 - acc: 0.7195 - val_loss: 0.7877 - val_acc: 0.7168
#
# Epoch 00035: val_loss improved from 0.79780 to 0.78771, saving model to model.weights.best.hdf5
# Epoch 36/100
#  - 13s - loss: 0.7941 - acc: 0.7210 - val_loss: 0.7869 - val_acc: 0.7192
#
# Epoch 00036: val_loss improved from 0.78771 to 0.78691, saving model to model.weights.best.hdf5
# Epoch 37/100
#  - 13s - loss: 0.7910 - acc: 0.7229 - val_loss: 0.7850 - val_acc: 0.7198
#
# Epoch 00037: val_loss improved from 0.78691 to 0.78505, saving model to model.weights.best.hdf5
# Epoch 38/100
#  - 13s - loss: 0.7904 - acc: 0.7204 - val_loss: 0.7781 - val_acc: 0.7252
#
# Epoch 00038: val_loss improved from 0.78505 to 0.77806, saving model to model.weights.best.hdf5
# Epoch 39/100
#  - 13s - loss: 0.7850 - acc: 0.7239 - val_loss: 0.7784 - val_acc: 0.7230
#
# Epoch 00039: val_loss did not improve from 0.77806
# Epoch 40/100
#  - 13s - loss: 0.7785 - acc: 0.7273 - val_loss: 0.7785 - val_acc: 0.7256
#
# Epoch 00040: val_loss did not improve from 0.77806
# Epoch 41/100
#  - 13s - loss: 0.7721 - acc: 0.7309 - val_loss: 0.7764 - val_acc: 0.7288
#
# Epoch 00041: val_loss improved from 0.77806 to 0.77645, saving model to model.weights.best.hdf5
# Epoch 42/100
#  - 13s - loss: 0.7739 - acc: 0.7272 - val_loss: 0.7726 - val_acc: 0.7280
#
# Epoch 00042: val_loss improved from 0.77645 to 0.77256, saving model to model.weights.best.hdf5
# Epoch 43/100
#  - 13s - loss: 0.7705 - acc: 0.7299 - val_loss: 0.7710 - val_acc: 0.7288
#
# Epoch 00043: val_loss improved from 0.77256 to 0.77100, saving model to model.weights.best.hdf5
# Epoch 44/100
#  - 13s - loss: 0.7655 - acc: 0.7288 - val_loss: 0.7685 - val_acc: 0.7286
#
# Epoch 00044: val_loss improved from 0.77100 to 0.76848, saving model to model.weights.best.hdf5
# Epoch 45/100
#  - 13s - loss: 0.7638 - acc: 0.7320 - val_loss: 0.7707 - val_acc: 0.7302
#
# Epoch 00045: val_loss did not improve from 0.76848
# Epoch 46/100
#  - 13s - loss: 0.7604 - acc: 0.7362 - val_loss: 0.7709 - val_acc: 0.7264
#
# Epoch 00046: val_loss did not improve from 0.76848
# Epoch 47/100
#  - 13s - loss: 0.7572 - acc: 0.7320 - val_loss: 0.7616 - val_acc: 0.7292
#
# Epoch 00047: val_loss improved from 0.76848 to 0.76164, saving model to model.weights.best.hdf5
# Epoch 48/100
#  - 13s - loss: 0.7514 - acc: 0.7363 - val_loss: 0.7707 - val_acc: 0.7296
#
# Epoch 00048: val_loss did not improve from 0.76164
# Epoch 49/100
#  - 13s - loss: 0.7507 - acc: 0.7351 - val_loss: 0.7570 - val_acc: 0.7326
#
# Epoch 00049: val_loss improved from 0.76164 to 0.75695, saving model to model.weights.best.hdf5
# Epoch 50/100
#  - 13s - loss: 0.7481 - acc: 0.7379 - val_loss: 0.7643 - val_acc: 0.7324
#
# Epoch 00050: val_loss did not improve from 0.75695
# Epoch 51/100
#  - 13s - loss: 0.7464 - acc: 0.7380 - val_loss: 0.7701 - val_acc: 0.7300
#
# Epoch 00051: val_loss did not improve from 0.75695
# Epoch 52/100
#  - 13s - loss: 0.7412 - acc: 0.7383 - val_loss: 0.7644 - val_acc: 0.7296
#
# Epoch 00052: val_loss did not improve from 0.75695
# Epoch 53/100
#  - 13s - loss: 0.7410 - acc: 0.7388 - val_loss: 0.7571 - val_acc: 0.7298
#
# Epoch 00053: val_loss did not improve from 0.75695
# Epoch 54/100
#  - 13s - loss: 0.7339 - acc: 0.7424 - val_loss: 0.7478 - val_acc: 0.7328
#
# Epoch 00054: val_loss improved from 0.75695 to 0.74778, saving model to model.weights.best.hdf5
# Epoch 55/100
#  - 13s - loss: 0.7335 - acc: 0.7413 - val_loss: 0.7510 - val_acc: 0.7356
#
# Epoch 00055: val_loss did not improve from 0.74778
# Epoch 56/100
#  - 13s - loss: 0.7321 - acc: 0.7417 - val_loss: 0.7470 - val_acc: 0.7350
#
# Epoch 00056: val_loss improved from 0.74778 to 0.74700, saving model to model.weights.best.hdf5
# Epoch 57/100
#  - 13s - loss: 0.7288 - acc: 0.7455 - val_loss: 0.7479 - val_acc: 0.7360
#
# Epoch 00057: val_loss did not improve from 0.74700
# Epoch 58/100
#  - 13s - loss: 0.7249 - acc: 0.7457 - val_loss: 0.7460 - val_acc: 0.7376
#
# Epoch 00058: val_loss improved from 0.74700 to 0.74600, saving model to model.weights.best.hdf5
# Epoch 59/100
#  - 13s - loss: 0.7202 - acc: 0.7456 - val_loss: 0.7449 - val_acc: 0.7396
#
# Epoch 00059: val_loss improved from 0.74600 to 0.74493, saving model to model.weights.best.hdf5
# Epoch 60/100
#  - 13s - loss: 0.7233 - acc: 0.7455 - val_loss: 0.7476 - val_acc: 0.7368
#
# Epoch 00060: val_loss did not improve from 0.74493
# Epoch 61/100
#  - 13s - loss: 0.7140 - acc: 0.7494 - val_loss: 0.7401 - val_acc: 0.7414
#
# Epoch 00061: val_loss improved from 0.74493 to 0.74010, saving model to model.weights.best.hdf5
# Epoch 62/100
#  - 13s - loss: 0.7091 - acc: 0.7512 - val_loss: 0.7482 - val_acc: 0.7350
#
# Epoch 00062: val_loss did not improve from 0.74010
# Epoch 63/100
#  - 13s - loss: 0.7090 - acc: 0.7514 - val_loss: 0.7380 - val_acc: 0.7400
#
# Epoch 00063: val_loss improved from 0.74010 to 0.73797, saving model to model.weights.best.hdf5
# Epoch 64/100
#  - 13s - loss: 0.7049 - acc: 0.7521 - val_loss: 0.7356 - val_acc: 0.7444
#
# Epoch 00064: val_loss improved from 0.73797 to 0.73560, saving model to model.weights.best.hdf5
# Epoch 65/100
#  - 13s - loss: 0.7094 - acc: 0.7498 - val_loss: 0.7388 - val_acc: 0.7404
#
# Epoch 00065: val_loss did not improve from 0.73560
# Epoch 66/100
#  - 13s - loss: 0.7052 - acc: 0.7518 - val_loss: 0.7350 - val_acc: 0.7404
#
# Epoch 00066: val_loss improved from 0.73560 to 0.73497, saving model to model.weights.best.hdf5
# Epoch 67/100
#  - 13s - loss: 0.7015 - acc: 0.7544 - val_loss: 0.7357 - val_acc: 0.7426
#
# Epoch 00067: val_loss did not improve from 0.73497
# Epoch 68/100
#  - 13s - loss: 0.6935 - acc: 0.7586 - val_loss: 0.7342 - val_acc: 0.7432
#
# Epoch 00068: val_loss improved from 0.73497 to 0.73422, saving model to model.weights.best.hdf5
# Epoch 69/100
#  - 13s - loss: 0.6925 - acc: 0.7571 - val_loss: 0.7300 - val_acc: 0.7428
#
# Epoch 00069: val_loss improved from 0.73422 to 0.73003, saving model to model.weights.best.hdf5
# Epoch 70/100
#  - 13s - loss: 0.6937 - acc: 0.7564 - val_loss: 0.7292 - val_acc: 0.7464
#
# Epoch 00070: val_loss improved from 0.73003 to 0.72917, saving model to model.weights.best.hdf5
# Epoch 71/100
#  - 13s - loss: 0.6920 - acc: 0.7541 - val_loss: 0.7273 - val_acc: 0.7452
#
# Epoch 00071: val_loss improved from 0.72917 to 0.72729, saving model to model.weights.best.hdf5
# Epoch 72/100
#  - 13s - loss: 0.6922 - acc: 0.7574 - val_loss: 0.7245 - val_acc: 0.7458
#
# Epoch 00072: val_loss improved from 0.72729 to 0.72455, saving model to model.weights.best.hdf5
# Epoch 73/100
#  - 13s - loss: 0.6854 - acc: 0.7585 - val_loss: 0.7258 - val_acc: 0.7464
#
# Epoch 00073: val_loss did not improve from 0.72455
# Epoch 74/100
#  - 13s - loss: 0.6868 - acc: 0.7573 - val_loss: 0.7248 - val_acc: 0.7460
#
# Epoch 00074: val_loss did not improve from 0.72455
# Epoch 75/100
#  - 13s - loss: 0.6787 - acc: 0.7637 - val_loss: 0.7204 - val_acc: 0.7500
#
# Epoch 00075: val_loss improved from 0.72455 to 0.72040, saving model to model.weights.best.hdf5
# Epoch 76/100
#  - 13s - loss: 0.6754 - acc: 0.7624 - val_loss: 0.7219 - val_acc: 0.7500
#
# Epoch 00076: val_loss did not improve from 0.72040
# Epoch 77/100
#  - 13s - loss: 0.6768 - acc: 0.7619 - val_loss: 0.7214 - val_acc: 0.7492
#
# Epoch 00077: val_loss did not improve from 0.72040
# Epoch 78/100
#  - 13s - loss: 0.6757 - acc: 0.7627 - val_loss: 0.7198 - val_acc: 0.7508
#
# Epoch 00078: val_loss improved from 0.72040 to 0.71983, saving model to model.weights.best.hdf5
# Epoch 79/100
#  - 13s - loss: 0.6733 - acc: 0.7644 - val_loss: 0.7198 - val_acc: 0.7496
#
# Epoch 00079: val_loss improved from 0.71983 to 0.71978, saving model to model.weights.best.hdf5
# Epoch 80/100
#  - 13s - loss: 0.6697 - acc: 0.7659 - val_loss: 0.7168 - val_acc: 0.7506
#
# Epoch 00080: val_loss improved from 0.71978 to 0.71682, saving model to model.weights.best.hdf5
# Epoch 81/100
#  - 13s - loss: 0.6679 - acc: 0.7666 - val_loss: 0.7193 - val_acc: 0.7494
#
# Epoch 00081: val_loss did not improve from 0.71682
# Epoch 82/100
#  - 13s - loss: 0.6635 - acc: 0.7681 - val_loss: 0.7148 - val_acc: 0.7496
#
# Epoch 00082: val_loss improved from 0.71682 to 0.71478, saving model to model.weights.best.hdf5
# Epoch 83/100
#  - 13s - loss: 0.6633 - acc: 0.7664 - val_loss: 0.7142 - val_acc: 0.7504
#
# Epoch 00083: val_loss improved from 0.71478 to 0.71422, saving model to model.weights.best.hdf5
# Epoch 84/100
#  - 13s - loss: 0.6656 - acc: 0.7669 - val_loss: 0.7131 - val_acc: 0.7510
#
# Epoch 00084: val_loss improved from 0.71422 to 0.71307, saving model to model.weights.best.hdf5
# Epoch 85/100
#  - 13s - loss: 0.6571 - acc: 0.7692 - val_loss: 0.7137 - val_acc: 0.7512
#
# Epoch 00085: val_loss did not improve from 0.71307
# Epoch 86/100
#  - 13s - loss: 0.6608 - acc: 0.7683 - val_loss: 0.7095 - val_acc: 0.7522
#
# Epoch 00086: val_loss improved from 0.71307 to 0.70948, saving model to model.weights.best.hdf5
# Epoch 87/100
#  - 13s - loss: 0.6544 - acc: 0.7706 - val_loss: 0.7099 - val_acc: 0.7528
#
# Epoch 00087: val_loss did not improve from 0.70948
# Epoch 88/100
#  - 13s - loss: 0.6537 - acc: 0.7703 - val_loss: 0.7099 - val_acc: 0.7514
#
# Epoch 00088: val_loss did not improve from 0.70948
# Epoch 89/100
#  - 13s - loss: 0.6535 - acc: 0.7706 - val_loss: 0.7250 - val_acc: 0.7452
#
# Epoch 00089: val_loss did not improve from 0.70948
# Epoch 90/100
#  - 13s - loss: 0.6507 - acc: 0.7707 - val_loss: 0.7069 - val_acc: 0.7528
#
# Epoch 00090: val_loss improved from 0.70948 to 0.70694, saving model to model.weights.best.hdf5
# Epoch 91/100
#  - 13s - loss: 0.6500 - acc: 0.7707 - val_loss: 0.7042 - val_acc: 0.7534
#
# Epoch 00091: val_loss improved from 0.70694 to 0.70416, saving model to model.weights.best.hdf5
# Epoch 92/100
#  - 13s - loss: 0.6416 - acc: 0.7758 - val_loss: 0.7039 - val_acc: 0.7560
#
# Epoch 00092: val_loss improved from 0.70416 to 0.70394, saving model to model.weights.best.hdf5
# Epoch 93/100
#  - 13s - loss: 0.6401 - acc: 0.7746 - val_loss: 0.7027 - val_acc: 0.7552
#
# Epoch 00093: val_loss improved from 0.70394 to 0.70268, saving model to model.weights.best.hdf5
# Epoch 94/100
#  - 13s - loss: 0.6407 - acc: 0.7761 - val_loss: 0.7064 - val_acc: 0.7526
#
# Epoch 00094: val_loss did not improve from 0.70268
# Epoch 95/100
#  - 13s - loss: 0.6392 - acc: 0.7782 - val_loss: 0.7042 - val_acc: 0.7540
#
# Epoch 00095: val_loss did not improve from 0.70268
# Epoch 96/100
#  - 13s - loss: 0.6360 - acc: 0.7772 - val_loss: 0.7068 - val_acc: 0.7560
#
# Epoch 00096: val_loss did not improve from 0.70268
# Epoch 97/100
#  - 13s - loss: 0.6344 - acc: 0.7798 - val_loss: 0.6975 - val_acc: 0.7552
#
# Epoch 00097: val_loss improved from 0.70268 to 0.69753, saving model to model.weights.best.hdf5
# Epoch 98/100
#  - 13s - loss: 0.6350 - acc: 0.7795 - val_loss: 0.7061 - val_acc: 0.7544
#
# Epoch 00098: val_loss did not improve from 0.69753
# Epoch 99/100
#  - 13s - loss: 0.6322 - acc: 0.7754 - val_loss: 0.7003 - val_acc: 0.7554
#
# Epoch 00099: val_loss did not improve from 0.69753
# Epoch 100/100
#  - 13s - loss: 0.6256 - acc: 0.7820 - val_loss: 0.7007 - val_acc: 0.7566
#
# Epoch 00100: val_loss did not improve from 0.69753

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.7468

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
